# %% [markdown]
# Using IPython Notebook to analyze Django Model data
# ===================================================

# %% [markdown]
# Who Am I?
# =========

# %% [markdown]
# Adam Haney
# ----------
#   - ![Adam](https://s3.amazonaws.com/bellhops/img/Haney+Jpeg.jpg "Optional title")
#   - @adamhaney
#   - strayentrepreneur.com
#   - adam.haney@campusbellhops.com

# %% [markdown]
# # Who Here Has used IPython Notebook?

# %% [markdown]
# An Introduction to IPython Notebook
# ===================================

# %% [markdown]
# IPython Notebook is an HTML and ajax based "notebook" that allows developers to iteratively work through their ideas.

# %% [markdown]
# Demo
# ----

# %%
from IPython.display import Image

Image('bill_fail.jpg')

# %%
def small_part_of_problem(x, y):
    return x + y

# %%
computed_small_part_of_problem = small_part_of_problem(2, 2)

# %% [markdown]
# Now Using it with Django
# ========================

# %% [markdown]
# As a replacement for manage.py
# ==============================

# %% [markdown]
# Simple Data Visualization
# =========================

# %% [markdown]
# Using Pandas to answer more complicated questions
# =================================================
#
#   - User retention?

# %% [markdown]
# Using Vega / Vincent to visualize geospatial data
# =================================================

# %% [markdown]
# Exporting Slides
# ================
#
#   - pygments
#   - pandoc (http://johnmacfarlane.net/pandoc/installing.html, not pip installable)
#   - ipython nbconvert notebooks/slides.ipynb --to slides --post serve

# %% [markdown]
# IPython Roadmap
# ===============
#
#   - NSF grant
#   - Microsoft grant
#   - nbconvert
#   - new features

# %%
2 + 2
# Out:
# 4
